# %% [markdown]
# # **MainFlow Task 1 **

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# **Data Loading**

# %%
Student= pd.read_csv("/content/student-mat.csv",sep=";")
# ----------OR--------------
Student= pd.read_csv("student-mat.csv",sep=";")

# %%
Student.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %% [markdown]
# **Data Exploration**

# %%
Student.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
# ...

# %%
Student.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
Student.dtypes
# Out:
# school        object
# sex           object
# age            int64
# address       object
# famsize       object
# Pstatus       object
# Medu           int64
# Fedu           int64
# Mjob          object
# Fjob          object
# reason        object
# guardian      object
# traveltime     int64
# studytime      int64
# failures       int64
# schoolsup     object
# famsup        object
# paid          object
# activities    object
# nursery       object
# higher        object
# internet      object
# romantic      object
# famrel         int64
# freetime       int64
# goout          int64
# Dalc           int64
# Walc           int64
# health         int64
# absences       int64
# G1             int64
# G2             int64
# G3             int64
# dtype: object

# %%
Student.shape
# Out:
# (395, 33)

# %% [markdown]
# **Data Cleaning**

# %%
Student.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 390    False
# 391    False
# 392    False
# 393    False
# 394    False
# Length: 395, dtype: bool

# %% [markdown]
# **Data Analysis Questions**

# %%
# What is the average score in math (G3)?

average_G3=Student['G3'].mean()
average_G3
# Out:
# 10.415189873417722

# %%
# How many students scored above 15 in their final grade (G3)?

Student[Student['G3']>15].sum().shape[0]
# Out:
# 33

# %%
# Is there a correlation between study time (study time) and the final grade (G3)?

Student['studytime'].corr(Student['G3'])
# Out:
# 0.09781968965319626

# %%
# Which gender has a higher average final grade (G3)?

avg_by_gender=Student.groupby('sex')['G3'].mean()
print ("Average G3 by gender",avg_by_gender)

if avg_by_gender['F']>avg_by_gender['M']:
  print("Females has higher average in final grade G3")
else:
  print("Males has higher average in final grade G3")
# Out:
# Average G3 by gender sex
# F     9.966346
# M    10.914439
# Name: G3, dtype: float64
# Males has higher average in final grade G3

# %% [markdown]
# **Data Visualisation**

# %%
# Plot a histogram of final grades (G3).

plt.figure(figsize=(6, 4))
plt.hist(Student['G3'], bins=15, color='skyblue', edgecolor='black', alpha=0.7)
plt.title('Histogram of Final Grades (G3)', fontsize=16)
plt.xlabel('Final Grade (G3)', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# Create a scatter plot between study time (study time) and final grade (G3).

plt.figure(figsize=(6,4))
plt.scatter(Student['studytime'], Student['G3'], color='blue', alpha=0.6, edgecolor='black')
plt.title('Scatter Plot: Study Time vs Final Grade', fontsize=16)
plt.xlabel('Study Time', fontsize=14)
plt.ylabel('Final Grade (G3)', fontsize=14)
plt.grid(alpha=0.3)
plt.show()

# %%
# Create a bar chart comparing the average scores of male and female students.

plt.figure(figsize=(8, 6))
avg_by_gender.plot(kind='bar', color=['blue', 'red'], edgecolor='black', alpha=0.5)
plt.title('Average Final Grades by Gender', fontsize=16)
plt.xlabel('Gender', fontsize=14)
plt.ylabel('Average Final Grade (G3)', fontsize=14)
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
